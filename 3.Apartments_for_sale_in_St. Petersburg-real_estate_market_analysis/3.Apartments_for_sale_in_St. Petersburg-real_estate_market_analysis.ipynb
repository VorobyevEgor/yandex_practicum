# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!👋</b>
#
# Меня зовут Огурлиев Анзор, я буду ревьюером твоего проекта. Сразу хочу предложить тебе общаться на "ты", если тебе это неудобно, скажи мне об этом. Нам предстоит пройти с тобой через тернистый и от того интересный путь анализа данных! Можешь не переживать, я всегда помогу тебе, если у тебя возникнут вопросы)
#
# По ходу твоей работы я буду оставлять свои комментарии, по выполненным тобой шагам. Попрошу тебя не удалять их, так мне будет проще отслеживать твой прогресс в случае повторной проверки.
#
# Очень важно вести диалог и обсуждать те пункты, которые у тебя могли не получиться, поэтому, ты можешь оставлять свои комментарии, и мы обязательно во всем разберемся! Самое главное - выделяй свои комментарии удобным для тебя способом (цвет, рамка), но так, чтобы они отчетлитво отличались от моих комментариев. Так мы ни в чем не запутаемся)
#
# Свои комментарии я буду выделять так: <font color='green'>зеленый</font>, <font color='gold'>желтый</font> и <font color='red'>красный</font> цвет, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Этот комментарий я буду оставлять, если твое решение оптимально для данного шага.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Это не означает, что ты совершил ошибку. Такими комментариями я буду отмечать места, где ты справился с задачей, но её можно решить ещё лучше. Также в таких комментариях я буду оставлять для тебя другие советы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Если решение, которое ты применил на определенном шаге, требует значительных изменений, то я буду оставлять такой комментарий. Тебе нужно будет подумать еще раз как правильным образом решить данный этап. Если ревью содержит такие комментарии, то я не смогу принять проект с первого раза.
# </div>
#
# P.S. В оглавлении комментария ты увидишь `V1` (`V1`, `V2`, `V3`) - это версия моего комментария, которая понадобится нам с тобой, чтобы не запутаться, если потребуется оставить тебе комментарии после первой проверки.

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что начинаешь проект с описания.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
# импортируем базы данных pandas, numpy, matplotlib и seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# читаем файл real_estate_data.csv из папки /datasets/, указав в качестве разделителя знак табуляции \t, 
#     и сохраним результат в датафрейме data
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
# посмотрим на сам датафрейм, основную информацию о нем, и построим общую гистограмму для всех столбцов таблицы
display(data.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
# посмотрим на основную информацию о датафрейме
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
# Смотрим кол-во дубликатов
data.duplicated().sum()
# Out:
# 0

# %%
# Посмотрим на статистические данные, которые дают представление о распределение значений (округлив до сотых после запятой)
data.describe().round(2)
# Out:
#        total_images    last_price  total_area     rooms  ceiling_height  \
# count      23699.00  2.369900e+04    23699.00  23699.00        14504.00
# mean           9.86  6.541549e+06       60.35      2.07            2.77
# std            5.68  1.088701e+07       35.65      1.08            1.26
# min            0.00  1.219000e+04       12.00      0.00            1.00
# 25%            6.00  3.400000e+06       40.00      1.00            2.52
# 50%            9.00  4.650000e+06       52.00      2.00            2.65
# 75%           14.00  6.800000e+06       69.90      3.00            2.80
# max           50.00  7.630000e+08      900.00     19.00          100.00
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count      23613.00     21796.00  23699.00      21421.00  12180.00
# mean          10.67        34.46      5.89         10.57      1.15
# std            6.60        22.03      4.89          5.91      1.07
# ...

# %% [markdown]
# ***Подвывод на основе статистических данных***
#
# Минимальная площадь 12 м², а число комнат 0 - возможно это студии, а возможно ошибки.
# При этом общая площадь в 900 м², кол-во комнат 19, площадь кухни в 112 м² скорее всего будут аномальными значениями для нашей выборки.
# А вот высота потолков в 1 метр (минимальная) и 100 метров (максимальная) точно ошибка.
#
# По информации википедии (https://ru.wikipedia.org/wiki/Список_самых_высоких_зданий_Санкт-Петербурга) топ три  высокоэтажных здания это Лахта-центр - 88 этажа, Лидер Тауэр - 42 этажа и ЖК «Князь Александр Невский» - 37 этажей. В нашем списке самое высокое здание в 60 этажей - ошибка или аномалия? будем разбираться
#
# Минимальная жилая площадь в 2 м² и площадь кухни 1,3 м² очень похожи на некорректные данные. Удалять?.
#
# Минимальное расстояние до аэропорта 0 м невозможно. Либо данных нет и заполнили нулем, либо ошибка.

# %%
# построим общую гистограмму для всех столбцов таблицы (используем plt.show() для того, 
#             что бы не ввыводить на экран текстовую информацию перед таблицами)
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# ***Вывод***
# В нашей таблице 23699 записи. При этом во многих столбцах есть пропущенные значения и некорректный тип данных. Присутсвуют анамальные значения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно рассмотрел данные, с которыми предстоит работать.

# %% [markdown]
# ### Предобработка данных

# %%
# Приведем названия столбцов к общему виду
data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest', 
                            'parks_around3000': 'parks_around_3000', 
                            'ponds_around3000': 'ponds_around_3000'})

# %%
# Проверим кол-во пропусков в столбцах датафрейма
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
# Заменим типы данных и некоторые пропуски:
# для стоимости квартиры - целочисленный тип
data['last_price'] = data['last_price'].astype(int)

# дату публикации меняем на тип даты
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# число балконов - целое число. 
# Пропущенные значения примим за то, что балкон отсутсвует, поэтому его и не указали.
data['balcony'] = data['balcony'].fillna(value = 0).astype(int)

# Апартаменты - 20924 пропусков. Можно предположить, что не указывали тип недвижимости, потому что она просто жилая.
# Столбец булев тип данных, пропуски можно заменить на False
data['is_apartment'].fillna(False, inplace=True)
data['is_apartment'] = data['is_apartment'].astype('bool')

# число парков в радиусе 3 км - целое число. 
# Пропущенные значения примим за то, что парков в данном радиусе нет, поэтому их количество не указано.
data['parks_around_3000'] = data['parks_around_3000'].fillna(value = 0).astype(int)

# число водоёмов в радиусе 3 км - целое число.
# Пропущенные значения примим за то, что водоемов в данном радиусе нет, поэтому их количество не указано.
data['ponds_around_3000'] = data['ponds_around_3000'].fillna(value = 0).astype(int)

# сколько дней было размещено объявление (от публикации до снятия) - тоже целое число
# Предположим, что пропущенные значения это те, где объявление еще не снято , продолжает быть актуальным. 
# Тогда установим значение для таких записей - 9999 дней (около 27 лет, что не повлияет на данные,
# т.к. data['first_day_exposition'].min() = 2014г) 
data['days_exposition'].fillna(value = 9999, inplace=True)
data['days_exposition'] = data['days_exposition'].astype(int)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно обработал пропуски и типы данных в параметрах выше.
#
# Не понятен комментарий с параметром days_exposition, причем здесь 27 лет. Если это заглушка, то не забудь её потом убрать при анализе этого параметра, если это не заглушка то заполнять пропуски этим значением ошибочно.

# %%
# Посмотрим на количество домов с определенной этажностью, отсортировав по возрастанию таких объектов 
#     и добавив дома с пропущенными значениями
data['floors_total'].value_counts(ascending=True, dropna=False)
# Out:
# 60.0       1
# 33.0       1
# 37.0       1
# 29.0       1
# 34.0       1
# 52.0       1
# 36.0       3
# 28.0      21
# 35.0      24
# 1.0       25
# NaN       86
# 26.0     124
# 21.0     158
# 27.0     164
# 11.0     203
# 13.0     229
# 20.0     271
# 22.0     286
# 19.0     339
# 23.0     352
# 15.0     365
# 2.0      383
# 8.0      390
# 24.0     469
# 18.0     505
# 14.0     553
# 7.0      592
# 3.0      668
# 17.0     833
# 6.0      914
# 25.0    1075
# 10.0    1174
# 4.0     1200
# 12.0    1362
# 16.0    1376
# 9.0     3761
# 5.0     5788
# Name: floors_total, dtype: int64

# %%
# Посмотрим срез датафрейма по количеству пропущенных значений в этажности дома, но с указанным этажом квартиры
data.loc[data['floors_total'].isna() == True, 'floor'].value_counts()
# Out:
# 4     10
# 6      9
# 8      8
# 12     6
# 9      5
# 3      4
# 5      4
# 7      4
# 21     4
# 15     3
# 19     3
# 18     3
# 1      3
# 13     3
# 11     3
# 10     3
# 14     2
# 2      2
# 20     2
# 24     2
# 17     1
# 22     1
# 23     1
# Name: floor, dtype: int64

# %% [markdown]
# **Подвывод**
# По полученным данным мы видим, что доля квартир с пропущенными значениями этажности дома слишком мала.
# Можем предположить, что этажность дома забыли указать из-за того, что квартира находится на последнем этаже.
# Просмотрев в данных обьектах недвижимоти указзаный этаж, видим, что анамальных значений нет.
# Таким образом приравняем указанный этаж к этажности дома.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Проще сразу удалить эти объявления, их очень мало.

# %%
# заменим пропущенные значения в "этажности дома" на этаж, приняв его как последний в доме
for n in data['floor'].unique():
    data.loc[(data['floor'] == n) & (data['floors_total'].isna()), 'floors_total'] = data.loc[(data['floor'] == n), 'floors_total'].min()
# смотрим как сработала замена, пропали ли NaN значения
data['floors_total'].value_counts(ascending=True, dropna=False)
# Out:
# 60.0       1
# 33.0       1
# 37.0       1
# 29.0       1
# 34.0       1
# 52.0       1
# 36.0       3
# 28.0      21
# 35.0      24
# 1.0       28
# 26.0     124
# 21.0     162
# 27.0     164
# 11.0     206
# 13.0     232
# 20.0     273
# 22.0     287
# 19.0     342
# 23.0     353
# 15.0     368
# 2.0      385
# 8.0      398
# 24.0     471
# 18.0     508
# 14.0     555
# 7.0      596
# 3.0      672
# 17.0     834
# 6.0      923
# 25.0    1075
# 10.0    1177
# 4.0     1210
# 12.0    1368
# 16.0    1376
# 9.0     3766
# 5.0     5792
# Name: floors_total, dtype: int64

# %%
# Меняем тип данных на целочисленный
data['floors_total'] = data['floors_total'].astype(int)

# %%
data.plot(kind='hist', y='floors_total', bins=20, grid=True, figsize=(10, 6))
plt.show()
data.boxplot(column = 'floors_total', figsize=(10,8))
plt.title('Этажность здания')
plt.ylim(0, 60) 
plt.ylabel('Кол-во этажей')
plt.show()

# %% [markdown]
# Гисстограмма и график размаха показывают нам, что основная масса квартир находится в домах с этажностью от 1 до 28. Остальные дома можно убрать из выборки как аномальные

# %%
# Удалим отсутсвующие записи "название населённого пункта", благо их не много - 49шт
data.dropna(subset=['locality_name'], inplace=True)

# посмотрим на уникальыне значения столбца
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно.

# %%
#  В отличие от других населённых пунктов, посёлок может быть сельского или городского типа, поэтому
# переименуем "городской поселок", "поселок городского типа" и тд в "посёлок", а также объединим СНТ
    
data['locality_name'] = (data['locality_name'].str.replace('поселок', 'посёлок').str.replace
        ('садовое товарищество', 'садоводческое некоммерческое товарищество').str.replace
        ('посёлок станции', 'посёлок при железнодорожной станции').str.replace
        ('городской посёлок', 'посёлок').str.replace('посёлок городского типа', 'посёлок')
)

data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Большое Рейзино', 'деревня Большой Сабск', 'деревня Бор',
#        'деревня Борисова Грива', 'деревня Ваганово', 'деревня Вартемяги',
# ...

# %%
# Проверим, есть ли пропуски
data['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Стоило посмотреть на количество уникальных названий до и после обработки, чтобы ориентироваться еще больше. Все правильно в принципе сделал, можно было просто оставить только названия, удалив типы населенных пунктов, так все неявные дубликаты точно были бы обработаны.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента V1</b>
# Анзор, привет! Количество уникальных названий до и после смотрел, но удалил эти столбцы, почему то решил оставить только перечень наименований. По поводу оставить только названия населенного пункта, без село/поселок и т.д. не соглашусь. Наименование может быть одинаковое, а населенные пункты находится в разных местах. К примеру городской посёлок Никольский (из нашего датафрейма), координаты 60.917232, 34.069065, находится около города Подпорожье. А село Никольское, координаты 59.450971, 30.005177, уже находится в Гатчинском районе.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В твоем примере в 1 населенном пункте ~93 объявления, в другом 7, количество не такое, чтобы оно могло повлиять на анализ в принципе.

# %%
# Проверим столбец "высота потолков" на аномальные значения
data['ceiling_height'].sort_values().unique()
# Out:
# array([  1.  ,   1.2 ,   1.75,   2.  ,   2.2 ,   2.25,   2.3 ,   2.34,
#          2.4 ,   2.45,   2.46,   2.47,   2.48,   2.49,   2.5 ,   2.51,
#          2.52,   2.53,   2.54,   2.55,   2.56,   2.57,   2.58,   2.59,
#          2.6 ,   2.61,   2.62,   2.63,   2.64,   2.65,   2.66,   2.67,
#          2.68,   2.69,   2.7 ,   2.71,   2.72,   2.73,   2.74,   2.75,
#          2.76,   2.77,   2.78,   2.79,   2.8 ,   2.81,   2.82,   2.83,
#          2.84,   2.85,   2.86,   2.87,   2.88,   2.89,   2.9 ,   2.91,
#          2.92,   2.93,   2.94,   2.95,   2.96,   2.97,   2.98,   2.99,
#          3.  ,   3.01,   3.02,   3.03,   3.04,   3.05,   3.06,   3.07,
#          3.08,   3.09,   3.1 ,   3.11,   3.12,   3.13,   3.14,   3.15,
#          3.16,   3.17,   3.18,   3.2 ,   3.21,   3.22,   3.23,   3.24,
#          3.25,   3.26,   3.27,   3.28,   3.29,   3.3 ,   3.31,   3.32,
#          3.33,   3.34,   3.35,   3.36,   3.37,   3.38,   3.39,   3.4 ,
# ...

# %%
# Предположим, что высота потолков в домах с одинаковой этажностью идентична.
# Тогда заполним пропуски в столбце "высота потолков" медианными значениями по каждому многоэтажному дому. 
# Выбираем медиану из-за того, что она дает нам представление о том, 
#     где находится «центр» набора данных. Это также дает нам представление о «типичном» значении в данном наборе данных.
for floor in data['floors_total'].unique():
    data.loc[(data['floors_total'] == floor) & (data['ceiling_height'].isna()), 
             'ceiling_height'] = data.loc[(data['floors_total'] == floor), 'ceiling_height'].median()
    
data['ceiling_height'].isna().sum()
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# 1

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно обработал, молодец!

# %%
# Заменим явно "ошибочные" значения в столбце "высота потолков"
def wrong_ceiling_height(height):
    try:
        if height < 11:
            return height
        elif 11 <= height <= 100:
            return height / 10
    except:
        pass
# применим нашу функцию к столбцу
data['ceiling_height'] = data['ceiling_height'].apply(wrong_ceiling_height)
# построим гистограмму
data.plot(kind='hist', y='ceiling_height', bins=30, grid=True, figsize=(10, 6), xticks=np.linspace(1, 10, 10))
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно обработал.

# %% [markdown]
# По гистограмме мы видим, что основная масса значений находится в диапозоне от 2.2 до 3.2, с пиком в 2.7

# %%
data.boxplot(column = 'ceiling_height', figsize=(10,8))
plt.title('Высота потолков')
plt.ylim(0, 9) 
plt.ylabel('Высота, м')
plt.show()

# %% [markdown]
# По графику видно, что значения меньше 2,2 м и более 3,1 м являются аномальными

# %% [markdown]
# В Приказе Минземстроя №37 от 04.08.1998 года указано: Жилая площадь квартиры – это сумма всех жилых комнат недвижимости.
#
# Расчет площади происходит следующим образом:
#
# общая площадь – жилые комнаты + подсобные помещения + балконы, лоджии;
#
# жилая площадь – спальни, гостевые комнаты + кухня, коридор, лоджия (в случае, если была проведена перепланировка и квартира сделана студией).
#
# Из известных параметров у нас только: общая площадь, площадь кухни и жилая площадь. Площадных данных о подсобных помещениях и балконах/лоджий у нас нет, следовательно вышепредставленные расчеты мы не можем использовать.
#
# Для столбца "kitchen_area" по месту локации объекта недвижимости рассчитаем медианы соотношения площади кухни и общей площади, затем заполним пропуски, умножив найденную медиану на общую площадь объекта. Для "living_area" будем использовать еще показатели количества комнат.

# %%
# Заполним пропуски
median_kitchen_area = data.groupby('locality_name')['kitchen_area'].median() 
median_total_area = data.groupby('locality_name')['total_area'].median() 
part_kitchen_area = median_kitchen_area / median_total_area 
for locality in part_kitchen_area.index: 
    data.loc[((data['locality_name'] == locality) &  
(data['kitchen_area'].isna())), 'kitchen_area'] = data.loc[:, 'total_area'] * part_kitchen_area[locality] 
data['kitchen_area'].isna().sum()
# Out:
# 19

# %%
# оставшиеся 19 объектов заполним из принципа медиан соотношений площади кухни и общей площади квартиры умноженную на общую площадь
# (без привязки к местности)
data['kitchen_area'].fillna((data['kitchen_area'].median() /  data['total_area'].median()) * data['total_area'], inplace=True)
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный способ обработки пропусков в площадях, так держать!

# %%
data.plot(kind='hist', y='kitchen_area', bins=20, grid=True, figsize=(16, 6))
plt.show()
data.boxplot(column = 'kitchen_area', figsize=(14,8))
plt.title('Площадь кухни')
plt.ylim(0, 120) 
plt.ylabel('Площадь')
plt.show()

# %% [markdown]
# Из графиков видно, что основная часть квартир имеют площадь кухни до 18 кв.м

# %%
# пропущенные значения по "жилой площади" заполним медианными значениями по всем типам количетва комнат в населенном пункте
locality_rooms_living_area = data.groupby(['locality_name', 'rooms'])['living_area'].median()
locality_rooms_total_area = data.groupby(['locality_name', 'rooms'])['total_area'].median()
part_living_area = locality_rooms_living_area / locality_rooms_total_area 
for locality, room in part_living_area.index:
    data.loc[((data['locality_name'] == locality) & (data['rooms'] == room) & (data['living_area'].isna())), 
             'living_area'] = data.loc[:, 'total_area'] * part_living_area[locality] 
# проверяем заполнение
data['living_area'].isna().sum()
# Out:
# 1896

# %% [markdown]
# Как видим, из такого расчета соотношений мы смогли заполнить только 2 пропуска.
# Остальные пропущенные значения по "жилой площади" заполним медианными значениями по всем типам количетва комнат без привязки к территории.

# %%
# заполняем
for room in data['rooms'].unique():
    data.loc[((data['rooms'] == room) & (data['living_area'].isna())), 
             'living_area'] = data.loc[(data['rooms'] == room), 'living_area'].median()
# проверяем заполнение (попытка 2)
data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Жилую площадь тоже обработал верно, продолжай в том же духе!

# %%
# Пропуски в столбце "расстояние до центра города (м)" заполним средним значением до центра города в каждом населенном пункте 
for locality in data['locality_name'].unique():
    data.loc[(data['city_centers_nearest'].isna()) & (data['locality_name'] == locality),
             'city_centers_nearest'] = data.loc[(data['locality_name'] == locality), 'city_centers_nearest'].mean()
# смотрим заполнение
data['city_centers_nearest'].isna().sum()
# Out:
# 4864

# %%
# Так же заполняем и для расстояния до ближайшего аэропорта в метрах (м) 
for locality in data['locality_name'].unique():
    data.loc[(data['airports_nearest'].isna()) & (data['locality_name'] == locality),
             'airports_nearest'] = data.loc[(data['locality_name'] == locality), 'airports_nearest'].mean()
# смотрим заполнение
data['airports_nearest'].isna().sum()
# Out:
# 4864

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Можно в разбивке по городам заполнить для параметров выше пропуски, молодец, что оставшиеся пропуски не стал заполнять общим средним, это бы исказило статистики.

# %% [markdown]
# Остальные пропущенные значения оставим такими же, т.к. это картографические данные

# %%
# Посмотрим на диапозон количества комнат в представленных квартирах
data.plot(kind='hist', y='rooms', bins=20, grid=True, figsize=(14, 6))
plt.show()
data.boxplot(column = 'rooms', figsize=(14,6))
plt.title('Кол-во комнат в квартире')
plt.ylim(0, 15) 
plt.ylabel('Кол-во комнат')
plt.show()

# %%
# Удалим аномальные значения с параметром высоты потолка менее 2 м и более 5 м (плотность квартир с высотой с 3м до 5м
# не маленькая. Трогать их не будем, так как могу быть двух уровневые квартиры или с высокими потолками,), 
# а так же с количеством комнат более 8 (в таких квартирах, что количетсво комнат, что площадные значения выбиваются из выборки)
data = data.query('2.1 <= ceiling_height <= 5 and rooms <= 8')

# %%
data.describe().round(2)
# Out:
#        total_images    last_price  total_area     rooms  ceiling_height  \
# count      23600.00  2.360000e+04    23600.00  23600.00        23600.00
# mean           9.86  6.488597e+06       60.08      2.06            2.71
# std            5.68  1.044897e+07       34.38      1.04            0.23
# min            0.00  1.219000e+04       12.00      0.00            2.20
# 25%            6.00  3.400000e+06       40.00      1.00            2.55
# 50%            9.00  4.635500e+06       52.00      2.00            2.65
# 75%           14.00  6.760848e+06       69.60      3.00            2.75
# max           50.00  7.630000e+08      631.20      8.00            5.00
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count      23600.00     23600.00  23600.00      23600.00  23600.00
# mean          10.68        34.16      5.89         10.53      0.59
# std            6.59        21.00      4.88          5.96      0.96
# ...

# %% [markdown]
# ***Вывод***: выполнили предобработку данных:
#
# - Определили и заполнили пропущенные значения в столбцах.
#
# - Преобразовали типы данных в столбцах.
#
# - Выявили уникальные значения и изменили неявные дубликаты.
#
# - Нашли и устранили редкие и выбивающиеся значения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошо справился с данным пунктом, так держать!

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим в таблицу новые столбцы:
# - ***price_per_one_square_meter***: цена одного квадратного метра;
# - ***weekday***: день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - ***month***: месяц публикации объявления;
# - ***year***: год публикации объявления;
# - ***floor_category***: тип этажа квартиры (значения — «первый», «последний», «другой»);
# - ***city_centers_nearest_km***: расстояние до центра города в километрах (переведенное из м в км и округленное до целых значений).

# %%
# Добавим столбец с ценой за 1м² и приведем его в целочисленный тип
data['price_per_one_square_meter'] = data['last_price'] / data['total_area']
data['price_per_one_square_meter'] = data['price_per_one_square_meter'].astype(int)
# Out:
# /tmp/ipykernel_104/4088986846.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price_per_one_square_meter'] = data['last_price'] / data['total_area']
# /tmp/ipykernel_104/4088986846.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price_per_one_square_meter'] = data['price_per_one_square_meter'].astype(int)

# %% [markdown]
# Вопрос к ревьюеру:
#
# Почему возникает ошибка копии датафрейма? критично ли это? и что за собой влечет?

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В принципе на все это может ответить результат поискового запроса) Старайся сам искать ответы на свои вопросы, это пригодится при реальных задачах, когда некого будет спросить.
#
# Это не ошибка, просто предупреждение. Подробное описание есть здесь:
#
# https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
#
# Здесь тоже описано что является причиной:
#
# https://www.codecamp.ru/blog/pandas-settingwithcopywarning/

# %%
# Добавим столбец с днем недели публикации объявления
data['weekday'] = data['first_day_exposition'].dt.weekday

# Добавим столбец с месяцем публикации объявления
data['month'] = data['first_day_exposition'].dt.month

# Добавим столбец с годом публикации объявления
data['year'] = data['first_day_exposition'].dt.year
# Out:
# /tmp/ipykernel_104/3348899625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['weekday'] = data['first_day_exposition'].dt.weekday
# /tmp/ipykernel_104/3348899625.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['month'] = data['first_day_exposition'].dt.month
# /tmp/ipykernel_104/3348899625.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#напишем функцию категоризации по этажам, используя метод apply применимо к каждой строке датафрейма через axis = 1
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 < floor < floors_total:
        return 'другой'
    
# Добавляем столбец с категорией этажа квартиры
data['floor_category'] = data.apply(floor_category, axis = 1)

# %%
# Добавим столбец расстояние до центра города в километрах
data['city_centers_nearest_km'] = round(data['city_centers_nearest'] / 1000)

# %%
# Посмотрим как добавились столбцы
data.sample(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 10064            10     3000000        30.0           2017-09-11      1
# 9404             10     4850000        98.0           2019-01-27      3
# 13565            16     1700000        51.5           2018-03-03      2
# 7711             12     4799000        60.0           2017-04-18      2
# 14481            11    13990000        81.0           2017-08-21      3
# 4130              4     3300000        47.0           2018-09-11      1
# 5248              0     6650000        58.1           2017-12-09      3
# 15467            13     5300000        56.6           2018-09-19      3
# 14615            14     4450000        44.4           2018-11-10      2
# 17868            16     5900000        56.8           2018-06-21      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 10064            2.55             5         16.0      2         False  ...
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Новые столбцы создал правильно.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# ***Изучаем параметры объектов недвижимости***

# %%
#  Общая площадь

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['total_area'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='total_area', bins=30, grid=True, figsize=(8, 6), range=(8, 150), ec='black')
plt.title('Общая площадь объектов недвижимости')
plt.xlabel('м²')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'total_area', figsize=(8,6))
plt.title('Общая площадь объектов недвижимости')
plt.ylabel('м²')
plt.ylim(0, 150) 
plt.show()
# Out:
# count    23600.000000
# mean        60.075206
# std         34.379895
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.600000
# max        631.200000
# Name: total_area, dtype: float64

# %% [markdown]
# График размаха показывает, что основная часть квартир расположилась в диапозоне от 15 до 115 м² («Усы» простираются влево и вправо от границ ящика на расстояние, равное 1,5 межквартильного размаха). Первая и третья квартили - значения в 40 и 69 м² соответсвенно.
#
# Гистограмма говорит нам о том, что большая часть квартир находится в диапозоне от 30 до 65 м² с пиком примернов 45 м². Площади меньше 30 и больше 110 м² редки.

# %%
#  Жилая площадь

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['living_area'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='living_area', bins=30, grid=True, figsize=(8, 6), range=(0, 150), ec='black')
plt.title('Жилая площадь объектов недвижимости')
plt.xlabel('м²')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'living_area', figsize=(8,6))
plt.title('Жилая площадь объектов недвижимости')
plt.ylabel('м²')
plt.ylim(0, 150) 
plt.show()
# Out:
# count    23600.000000
# mean        34.162498
# std         20.996277
# min          2.000000
# 25%         18.400000
# 50%         30.300000
# 75%         42.600000
# max        347.500000
# Name: living_area, dtype: float64

# %% [markdown]
# Минимальная жилая площадь в 2 метра похожа на выброс. Пик по гистограмме 18 м², среднее значение 30 м². Основной диапозон жилой площади с 18 до 45 м².

# %%
#  Площадь кухни

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['kitchen_area'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='kitchen_area', bins=30, grid=True, figsize=(8, 6), range=(0, 60), ec='black')
plt.title('Площадь кухни объектов недвижимости')
plt.xlabel('м²')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'kitchen_area', figsize=(8,6))
plt.title('Площадь кухни объектов недвижимости')
plt.ylabel('м²')
plt.ylim(0, 100) 
plt.show()
# Out:
# count    23600.000000
# mean        10.525332
# std          5.963207
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max        107.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Среднее значение площади кухни 10,5 м², медиана - 9 м². Большая часть квартир имеет площадь кухни от 5 до 15 м². Также наблюдается небольшой "хвост" из-за редких, но больших значений

# %%
#  Цена объекта

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['last_price'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='last_price', bins=30, grid=True, figsize=(8, 6), range=(0, 20000000), ec='black')
plt.title('Цена объекта объектов недвижимости')
plt.xlabel('Стоимость, 10 млн руб.')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'last_price', figsize=(8,6))
plt.title('Цена объекта объектов недвижимости')
plt.ylabel('Стоимость, 10 млн руб.')
plt.ylim(0, 30000000) 
plt.show()
# Out:
# count    2.360000e+04
# mean     6.488597e+06
# std      1.044897e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.635500e+06
# 75%      6.760848e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Минимальная стоимость квартиры - 12190 руб. явно выброс Максимальная - 763 млн. руб. Пик количества квартир продаются по цене от 3.8 млн до 4.2 млн. руб. Хорошо заметен ниспадающий хвост из-за редких и дорогих предложений. Средняя (6,5 млн руб.) сильно разница с медианой в 4,6 млн. руб.

# %%
#  Количество комнат

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['rooms'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='rooms', bins=30, grid=True, figsize=(8, 6), range=(0, 8), ec='black')
plt.title('Количество комнат объектов недвижимости')
plt.xlabel('кол-во комнат')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'rooms', figsize=(8,6))
plt.title('Количество комнат объектов недвижимости')
plt.ylabel('кол-во комнат')
plt.ylim(0, 10) 
plt.show()
# Out:
# count    23600.000000
# mean         2.062585
# std          1.043333
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          8.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Самое большое количество квартир приходятся на однокомнатные и двухкомнтаные, на третьем месте - трехкомнатные (удивительно, неправда? :)) Медиана и среднее совпадают.

# %%
#  Высота потолков

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['ceiling_height'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='ceiling_height', bins=30, grid=True, figsize=(8, 6), range=(2.4, 3.2), ec='black')
plt.title('Высота потолков объектов недвижимости')
plt.xlabel('высота, м.')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'ceiling_height', figsize=(8,6))
plt.title('Высота потолков объектов недвижимости')
plt.ylabel('высота, м.')
plt.ylim(2, 6) 
plt.show()
# Out:
# count    23600.000000
# mean         2.707065
# std          0.229030
# min          2.200000
# 25%          2.550000
# 50%          2.650000
# 75%          2.750000
# max          5.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Самое большое кол-во квартир с высотой потолков 2,55 м. Рассматриваемый диапозон высоты потолков от 2,5м до 3м. Среднее и медиана почти что совпадают.

# %%
#  Этаж квартиры

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['floor'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='floor', bins=30, grid=True, figsize=(8, 6), range=(1, 33), ec='black')
plt.title('Этаж квартиры')
plt.xlabel('Этаж')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'floor', figsize=(8,6))
plt.title('Этаж квартиры')
plt.ylabel('Этаж')
plt.ylim(0, 35) 
plt.show()
# Out:
# count    23600.000000
# mean         5.892119
# std          4.879276
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %% [markdown]
# Можно сказать, что квартиры выше 18 этажа - выбивающиеся значения. Большинство продающихся квартир расположены с 1 по 5 этаж.

# %%
#  Тип этажа квартиры

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['floor_category'].describe())
print('')

# Посмотрим на кол-во в каждой категории
print(data['floor_category'].value_counts())

# Построим столбчатый график
sns.countplot(data=data, x='floor_category', ec='black')
plt.title('Тип этажа квартиры')
plt.ylabel('Количество квартир')
plt.show()
# Out:
# count      23600
# unique         3
# top       другой
# freq       17298
# Name: floor_category, dtype: object
#
# другой       17298
# последний     3396
# первый        2906
# Name: floor_category, dtype: int64

# %% [markdown]
# Как мы можем видеть, объекты недвижимости, расположенные на первом и последним этажах имеют примерно одинаковые значения и их доля не столь велика. Большая часть объектов расположена на этажах между первым и последним

# %%
#  Общее количество этажей в доме

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['floors_total'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='floors_total', bins=30, grid=True, figsize=(8, 6), range=(0, 30), ec='black')
plt.title('Этажность дома')
plt.xlabel('кол-во этажей')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'floors_total', figsize=(8,6))
plt.title('Этажность дома')
plt.ylabel('кол-во этажей')
plt.ylim(0, 61)
plt.show()
# Out:
# count    23600.000000
# mean        10.676653
# std          6.589157
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Большинство квартир на продажу находятся на 6 и 10-этажках

# %%
#  Расстояние до центра города в метрах

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['city_centers_nearest'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='city_centers_nearest', bins=30, grid=True, figsize=(8, 6), range=(0, 60000), ec='black')
plt.title('Расстояние до центра города в метрах')
plt.xlabel('м.')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'city_centers_nearest', figsize=(8,6))
plt.title('Расстояние до центра города в метрах')
plt.ylabel('м.')
plt.ylim(0, 66000) 
plt.show()
# Out:
# count    18746.000000
# mean     14459.286181
# std       8597.713269
# min        181.000000
# 25%       9496.000000
# 50%      13266.000000
# 75%      16735.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# Среднее и медиана близки друг к другу. Большая часть квартир расположены на расстоянии 13-14 км от центра.

# %%
#  Расстояние до ближайшего аэропорта

# Уберем значения равные 0 
data = data.query('airports_nearest != 0')

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['airports_nearest'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='airports_nearest', bins=30, grid=True, figsize=(8, 6), range=(0, 85000), ec='black')
plt.title('Расстояние до ближайшего аэропорта')
plt.xlabel('м')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'airports_nearest', figsize=(8,6))
plt.title('Расстояние до ближайшего аэропорта')
plt.ylabel('м')
plt.ylim(0, 90000) 
plt.show()
# Out:
# count    18745.000000
# mean     29523.084515
# std      13050.695748
# min       6450.000000
# 25%      18794.000000
# 50%      27372.000000
# 75%      38722.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Ближайшая к аэропорту квартира находится в 6,45 км. Основная часть объектов расположена в диапозоне 12 - 55 км с пиком удаленности в 18-25 км.

# %%
#  Расстояние до ближайшего парка

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data['parks_nearest'].describe())

# Построим гисстограму и график размаха
data.plot(kind='hist', y='parks_nearest', bins=30, grid=True, figsize=(8, 6), range=(0, 1500), ec='black')
plt.title('Расстояние до ближайшего парка')
plt.xlabel('м')
plt.ylabel('Количество квартир')
plt.show()
data.boxplot(column = 'parks_nearest', figsize=(8,6))
plt.title('Расстояние до ближайшего парка')
plt.ylabel('м')
plt.ylim(0, 3200) 
plt.show()
# Out:
# count    8036.000000
# mean      491.070682
# std       342.936086
# min         1.000000
# 25%       287.750000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Рассматриваемый диапазон с 0 до 820 м. Большинство объектов недвижимости расположены на удалении от ближайшего парка на расстоянии 380-560м. Есть авру значений выбивающихся за 3000 м.

# %%
#  День и месяц публикации объявления

#  Посмотрим на статистические данные столбца, которые дают представление о распределение значений
print(data[['weekday', 'month']].describe())

# Построим столбчатый график
# data['weekday'].value_counts().plot.bar(figsize=(10, 10), ec='black', legend=True)
fig, axes = plt.subplots(1,2)
data['weekday'].value_counts().plot.bar(ax=axes[0], ec='black', legend=True, figsize=(10, 10))
axes[0].set_title('День публикации объявления')
axes[1].set_title('Месяц публикации объявления')
axes[0].set_ylabel('Количество квартир')
axes[0].set_xlabel('Дни')
axes[1].set_xlabel('Месяца')
data['month'].value_counts().plot.bar(ax=axes[1], ec='black', legend=True, figsize=(10, 10))
plt.show()
# Out:
#             weekday         month
# count  23599.000000  23599.000000
# mean       2.568499      6.402348
# std        1.788848      3.491716
# min        0.000000      1.000000
# 25%        1.000000      3.000000
# 50%        3.000000      6.000000
# 75%        4.000000     10.000000
# max        6.000000     12.000000

# %% [markdown]
# По графику видно, что чаще всего объявления публиковали в будние дни в середине недели. Реже в выходные дни.
#
# Относительно месяцов, то чаще объявления публиковали после в феврале. Наименьшие показатели в январе и мае. Возможно из-за большого количества выходных и праздничных дней.

# %% [markdown]
# ***Вывод:***
#
# Типичная квартира из исходных данных представляет из себя: 1 или 2 комнаты в 6-ти этажке (с квартирой с 2 по 5 этаж), общей площадью около 45 м², жилая площадь - 18 м², а площадь кухни около 8,5 м², с высотой потолков 2,55 м, стоимостью в районе 4 млн.руб, расположенной от центра на 13-14 км, а от аэропорта на 18-25 км, до ближайшего парка около 470 метров.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Замечательно проанализировал все случайные величины, похвально, что не ограничился просто гистограммами распределений, но также рассмотрел диаграммы размаха и статистики.

# %% [markdown]
# ***Изучение времени продажи квартиры***

# %%
# Проанализируем время продажи квартиры.
# Для этого посмотрим на статистические данные столбца, которые дают представление о распределение значений, 
# без учета активных на данный момент объявлений
print(data.query('days_exposition != 9999')['days_exposition'].describe())

# И посмотрим распределение по "виолончельному ключу"
sns.violinplot(data.loc[(data['days_exposition'] != 9999),'days_exposition'])
sns.set(rc={'figure.figsize':(16,10)})
plt.xlabel('Дни')
plt.xticks(ticks=np.arange(0,1580,50), fontsize=8)
plt.show()
# Out:
# count    20431.000000
# mean       180.641917
# std        219.596144
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Как видим по графику пик значений приходится на 45 дней, это меньше медианы в 95 дней.Имеем длинный хвост выбивающихся редких значений

# %%
# Сравним с гисстограмой
plt.hist(data.query('days_exposition != 9999')['days_exposition'], bins=100, range=(0,250))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# ***Вывод***
#
# Данные гисстограмы совпадают с виолончельным ключом. Мы видим следующее:
#
#  - Медианное время продажи - 95 дней. Среднее время продажи - 181 день.
#  - Квартили: первая - 45 дней (совпадает с пиком продаж), третья - 231 день. "Усы" расползаюся до 510 дней. Значения уползающие за эти параметры можно считать выбросами.
#  - В основном квартиры продаются за срок до 120 дней. Есть большое число квартир, проданных всего за несколько дней после публикации. А есть варианты, которые продавались и год.
#
# Идеальная продажая в срок до 45 дней. Долгой продажей - дольше 230 дней (7,5 месяцев).
#
# Так же есть вариант, что квартира не продана, а просто закрылось объявление в связи с истекшим сроком публикации, или клиент передумал продавать.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Именно так, все верно.

# %% [markdown]
# ***Факторы больше всего влияющие на общую (полную) стоимость объекта***

# %%
# Воспользуемся методом корреляции и хитмепом
# Нам нужен список с параметрами для проверки
corr_columns = [
    'last_price',
    'total_area',
    'living_area',
    'kitchen_area',
    'rooms',
    'city_centers_nearest_km',
    'weekday',
    'month',
    'year']
# выводим матрицу корреляции
corr_matrix = data[corr_columns].corr()
display(corr_matrix)
# Out:
#                          last_price  total_area  living_area  kitchen_area  \
# last_price                 1.000000    0.641686     0.545341      0.500975
# total_area                 0.641686    1.000000     0.906125      0.649323
# living_area                0.545341    0.906125     1.000000      0.442713
# kitchen_area               0.500975    0.649323     0.442713      1.000000
# rooms                      0.355601    0.752484     0.849089      0.310085
# city_centers_nearest_km   -0.217249   -0.242317    -0.236696     -0.191343
# weekday                    0.002714   -0.004054    -0.005904     -0.003922
# month                      0.001027    0.007018     0.001379      0.003863
# year                      -0.043815   -0.081287    -0.075498     -0.060878
#
#                             rooms  city_centers_nearest_km   weekday  \
# last_price               0.355601                -0.217249  0.002714
# total_area               0.752484                -0.242317 -0.004054
# ...

# %%
# Визуализируем
plt.figure(figsize = (16, 8))
sns.heatmap(corr_matrix, vmin=-1, vmax=1, cmap='coolwarm', annot=True)
plt.title('Матрица корреляции')
plt.show()

# %% [markdown]
# Что мы видим: наибольшая положительная линейная связь между стоимостью квартиры и ее площадью (0,64). Зависимость прямопропорциональная - чем больше стоимость квартиры, тем больше ее площадь. Положительная линейная связь для стоимости квартиры отмечается также с жилой площадью(0,55), площадью кухни(0,5), количеством комнат(0,36). Все эти факторы влияют на цену: чем больше жилая площадь и/или площадь и/или количество комнат, тем дороже квартира. Зависимость жилой площади и площади кухни к цене почти одинаковая, 0,5-0,55. Зависить кол-ва комнат к цене по сравнению общей площади к цене меньше почти в 2 раза. Не слишком большую отрициательную линейную связь можно заметить между стоимостью квартиры и расстоянием до центра города. Чем меньше расстояние до центра, тем больше стоимость квартиры. А вот между стоимостью квартиры и днем недели, месяцем или годом размещения объявления линейная связь отсутствует.

# %%
# Построим pair.plot для отображения зависимостей, исключив день, месяц и год, т.к. корреляция не показала зависимость
plt.figure(figsize = (16, 8))
sns.pairplot(data[['last_price',
    'total_area',
    'living_area',
    'kitchen_area',
    'rooms',
    'city_centers_nearest_km']])
plt.show()

# %% [markdown]
# Графики наглядно показывают нам корреляцию, зависимость параметров друг от друга, но рассмотрим детальнее каждый параметр, как он себя поведет по отношению к цене

# %%
# Зависимость цены от дня недели
data.plot(x = 'weekday', y = 'last_price', style='o', grid=True, figsize=(7, 5), alpha=0.5, color='green')
plt.title('Зависимость цены от дня недели')
plt.xlabel('день публикации')
plt.ylabel('стоимость, 100 млн.руб.')
plt.ylim(0, 100000000)
plt.show()

# Зависимость цены от месяца
data.plot(x = 'month', y = 'last_price', style='o', grid=True, figsize=(7, 5), alpha=0.5, color='green')
plt.title('Зависимость цены от месяца')
plt.xlabel('месяц публикации')
plt.ylabel('стоимость, 100 млн.руб.')
plt.ylim(0, 100000000)
plt.show()

# Зависимость цены от года
data.plot(x = 'year', y = 'last_price', style='o', grid=True, figsize=(7, 5), alpha=0.5, color='green')
plt.title('Зависимость цены от года')
plt.xlabel('год публикации')
plt.ylabel('стоимость, 100 млн.руб.')
plt.ylim(0, 100000000)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Для категориальных случайных величин лучше еще построить линейную или столбчатую диаграмму по сводной таблице, как ты сделал для типа этажа, чтобы посмотреть на тенденцию средней или медианной цены в зависимости от категории. Сейчас по графику можно сделать не полноценный или даже ошибочный вывод, не видно количество объявлений, средняя цена, можно оценить только выбросы.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента V1</b>
# Построим допалнительные графики, что бы понять, не допустил ли ошибку в выводе и при необходимости исправить ее.
#
# </div>

# %%
# Зависимость цены от дня недели

data.pivot_table(index='weekday', values='last_price', aggfunc='mean').plot(grid=True, style='o-', figsize=(10, 5))
plt.title('Зависимость медианной цены от дня недели')
plt.xlabel('день публикации')
plt.show()

# Зависимость цены от месяца

data.pivot_table(index='month', values='last_price', aggfunc='mean').plot(grid=True, style='o-', xlim=(1,12), figsize=(10, 5))
plt.title('Зависимость медианной цены от месяца')
plt.xlabel('месяц публикации')
plt.show()

# Зависимость цены от года

data.pivot_table(index='year', values='last_price', aggfunc='mean').plot(grid=True, style='o-', figsize=(10, 5))
plt.title('Зависимость медианной цены от года')
plt.xlabel('год публикации')
plt.show()

# %% [markdown]
# Как мы и говорили ранее, зависимоти между датой размещения объявления и стоимостью квартиры нет. Коэффициенты корреляции отрицательные и близятся к нулю. В 17 году было представленн больше "дорогих" квартир.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента V1</b>
#
# ***Измененный подвывод***
#
# Посмотрев на исправленные графики, можно подытожить тем, что:
#  - квартиры, размещенные на продажу в субботу, были значительно дороже объектов недвижимости выставленных на продажу в другие дни. Объявления за первую половину недели (с понедельника по среду) по цене почти что не отличаются. Воскрестные объявления самые дешевые.
#  -  В зависимости от месяца - мы видим резкое повышение цен в апреле, июле, сентября и декабре. Возможно это связано с началом финансового квартала (в случае с сентябрем -конец), люди могли получать премии на работе - ажиотаж на покупку квартиры возрастал.
#  - Относительно года - резкое падение медианой цены после 2014 года, и попытки возрастания цены только к 2019 году. Последствия финансового кризиса в 2014 году, резкий рост курса доллара и евро. Ажиотаж на покупку недвижимости был максимальный, а дальше, в следующих годах, у людей уже не было денег на покупку, спрос упал, цена тоже.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все верно, дополнительно если посмотреть на количество объявлений (это относится к последнему графику с годом размещения), то окажется, что такая высокая средняя цена в 2014 году может быть обусловлена просто небольшим числом объявлений в анализ попала подвыборка только дорогих квартир.

# %%
# Зависимость цены от площади
data.plot(x='total_area', y ='last_price', kind ='scatter', figsize=(7, 5), legend=True, alpha = 0.08, color='green')

plt.title('Зависимость цены от площади')
plt.xlabel('площадь, м²')
plt.ylabel('стоимость, 100 млн.руб.')
plt.xlim(0, 300)
plt.ylim(0, 100000000)
plt.show()

# %% [markdown]
# На графике видно прямопропорциональную зависимость, объекты недвижимости площадью до 150 кв. м. и стоимостью до 20 млн. руб. расположились плотно.

# %%
# Зависимость цены от жилой площади
data.plot(x='living_area', y ='last_price', kind ='scatter', figsize=(7, 5), legend=True, alpha = 0.05, color='green')

plt.title('Зависимость цены от жилой площади')
plt.xlabel('площадь, м²')
plt.ylabel('стоимость, 10 млн.руб.')
plt.xlim(0, 150)
plt.ylim(0, 40000000)
plt.show()

# %% [markdown]
# На графике видно прямопропорциональную зависимость, большинство данных для объектов недвижимости площадью до 65 кв. м. и стоимостью до 15 млн. руб.

# %%
# Зависимость цены от площади кухни
data.plot(x='kitchen_area', y ='last_price', kind ='scatter', figsize=(7, 5), legend=True, alpha = 0.05, color='green')

plt.title('Зависимость цены от площади кухни')
plt.xlabel('площадь, м²')
plt.ylabel('стоимость, 10 млн.руб.')
plt.xlim(0, 60)
plt.ylim(0, 60000000)
plt.show()

# %% [markdown]
# Изображена прямопропорциональная зависимость, большинство данных для объектов недвижимости с площадью кухни до 20 кв. м. и стоимостью до 18 млн. руб.

# %%
# Зависимость цены от кол-ва комнат
data.plot(x = 'rooms', y = 'last_price', style='o', grid=True, figsize=(7, 5), alpha=0.05, color='green')
plt.title('Зависимость цены от кол-ва комнат')
plt.xlabel('кол-во комнат')
plt.ylabel('стоимость, 100 млн.руб.')
plt.xlim(0, 8)
plt.ylim(0, 100000000)
plt.show()

# %% [markdown]
# Мы видим, что больше всего данных для квартир стоимостью до 30 млн. руб и кол-вом комнат от 1 до 4. С учеличение числа комнат с 1 до 3 комнат стоимость квартир растет, трех и четырех-комнатные квартиры по цене примерно одинаковы, а для пяти комнатных квартир стоимость уменьшается. Возможно это связано с тем, что такие квартиры старой застройки и в них маленькая площадь комнат.

# %%
# Зависимость цены от типа этажа
data.pivot_table(index='floor_category', values='last_price', aggfunc='median').plot(grid=True, 
                style='o-', figsize=(7, 5), color='green')
plt.show()

# %% [markdown]
# Из графика можно сделать вывод, что медианное значение стоимости квартир на первом этаже минимальное, за ними следуют квартиры на последнем этаже, для квартир, находящихся не на первом и последнем этаже - цена значительно выше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Остальные параметры рассмотрел правильно, выводы тоже написал отражающие действительность.

# %% [markdown]
# ***Средняя цена одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.***

# %%
# Посмотрим на топ-10 населенных пунктов с наибольшим числом объявлений
top_10_localities_name = data['locality_name'].value_counts().head(10)
top_10_localities_name
# Out:
# Санкт-Петербург      15682
# посёлок Мурино         556
# посёлок Шушары         440
# Всеволожск             397
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 235
# Name: locality_name, dtype: int64

# %%
# Сравним среднюю цену квадратного метра в топ-10 городов
top_10_pivot = (data.query(
    'locality_name in @top_10_localities_name.index').pivot_table(index='locality_name', values='price_per_one_square_meter')
)
# Преобразуем к целочислинному типу
top_10_pivot = top_10_pivot.astype(int)
# Отсортируем по убыванию
top_10_pivot.sort_values(by='price_per_one_square_meter', ascending=False)
# Out:
#                    price_per_one_square_meter
# locality_name
# Санкт-Петербург                        114733
# Пушкин                                 103125
# деревня Кудрово                         92473
# посёлок Парголово                       90175
# посёлок Мурино                          85681
# посёлок Шушары                          78676
# Колпино                                 75424
# Гатчина                                 68745
# Всеволожск                              68718
# Выборг                                  58237

# %%
# Для наглядности отобразим на графике
top_10_pivot.sort_values(by='price_per_one_square_meter').plot(kind='barh', 
                        legend=True, grid=True, ec='black', figsize=(8, 6), color='purple')

plt.title('Средняя цена за м²')
plt.xlabel('руб/м²')
plt.ylabel('')
plt.show()

# %% [markdown]
# ***Вывод***
#
# Наибольшая средняя стоимость квадратного метра в Санкт-Петербурге (удивительно, да?). На втором месте по стоимости - Пушкин, тоже ожидаемо, много исторических мест, неплохая застройка и большое количество парков. Затем идут районы, фактически являющиеся Санкт-Петербургом и непосредственно к нему примыкают. Наименьшая стоимость в Гатчине, Всеволожске и в маленьком, но очень красивом Выборге, находятся далеко от Санкт-Петербурга.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все так, самые дорогие квартиры в СПб, а дешевые в Выборге.

# %% [markdown]
# Вычислим среднюю цену каждого километра в Санкт-Петербурге

# %%
# Рассчитаем и посмотрим на график отображающий цену каждого км в Санкт-Петербурге
(
data.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='city_centers_nearest_km', values='price_per_one_square_meter')
    .plot(marker='o', grid=True, figsize=(14, 8), legend=False, color='purple', markerfacecolor='yellow')
)
plt.title('Средняя цена квадратного метра\nс шагом в 1 км до центра')
plt.xlabel('км')
plt.ylabel('руб./м²')
plt.xticks(ticks=np.arange(0,30,1), fontsize=8)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# В задании сказано, что нужно посмотреть на зависимость общей цены квартиры, а не цены за метр квадртный.

# %% [markdown]
# Максимальная цена за квадратный метр в 245 тыс. руб. в самом центре города, что не удивительно. Далее цена стремительно падает до радиуса в 3 км., возможно это связано с тем, что застройка старая, многим домам необходим капитальный ремонт. До радиуса в 7 км цена снова поднимается, более новые дома, а исторические места в шаговой доступности. После 7-го километра форма графика становится линейной и стоимость плавно начинается уменьшаться. Выбивающиеся по цене значения находятся в радиусе 27 км.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента V1</b>
#
# "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
#
# Упустил последнее предложение в задании, извиняюсь
#
# С помощью графика выше - "средней цены за квадратный метр", мы можем выделить "условный" центр города, это та точка, после которой идет явный спад в стоимости. В нашем случае это радиус 7 км.
#
# Построим график для цены объекта недвижимости в зависимости от километража
#
# </div>

# %%
# Рассчитаем и посмотрим на график отображающий цену объекта недвижимости в зависимости от центра Санкт-Петербурге

# добавим опцию, что бы цена у нас отображалась в полном формате, а не через "е"
pd.options.display.float_format

# выведем на экран сводную таблицу медианной (она честнее отображает цену) стоимости квартиры 
# в зависимости от удаленности от центра (радиус 7 км)
display(
    data.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km <=7')
    .pivot_table(index='city_centers_nearest_km',values='last_price', aggfunc='median')
)

# по этим данным так же строим граффик
(
data.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km <=7')
    .pivot_table(index='city_centers_nearest_km', values='last_price', aggfunc='median')
    .plot(marker='o', grid=True, figsize=(14, 8), legend=False, color='purple', markerfacecolor='yellow')
)
plt.title('Медианная цена объекта недвижимости\nс шагом в 1 км до центра Санкт-Петербурга')
plt.xlabel('км')
plt.ylabel(' 10 млн руб.')
plt.xticks(ticks=np.arange(0,8,1), fontsize=8)
plt.show()
# Out:
#                          last_price
# city_centers_nearest_km
# 0.0                        17900000
# 1.0                        11395000
# 2.0                        10000000
# 3.0                         8400000
# 4.0                         9200000
# 5.0                         9483000
# 6.0                         8895000
# 7.0                         7800000

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Подвывод</b>
# Как мы можем видеть, самые дорогие объекты недвижимости в самом центре со медианной стоимостью 17,9 млн рублей. Далее идет резкое падение цены до 8,4 млн. рублей на 3 км удаленности от центра. С 3 по 7 км - медианная цена плавно поднимается и спускается по дуге до суммы 7,8 млн. руб., с пиком цены на 5 км в 9 483 000 рублей.
#
# *Описать изменение цены можно так:* самые дорогие квартиры в сердце города, дальше цена варьируется в диапозоне двух млн. руб. без сильных и заметных скачков.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Лучше было бы рассмотреть все расстояние, не только 7 км, ниже вывел график, видно, что цена на самом деле не колеблется в одном диапазоне, а падает.

# %%
# Рассчитаем и посмотрим на график отображающий цену объекта недвижимости в зависимости от центра Санкт-Петербурге

# добавим опцию, что бы цена у нас отображалась в полном формате, а не через "е"
pd.options.display.float_format

# выведем на экран сводную таблицу медианной (она честнее отображает цену) стоимости квартиры 
# в зависимости от удаленности от центра (радиус 7 км)
display(
    data.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='city_centers_nearest_km',values='last_price', aggfunc='median')
)

# по этим данным так же строим граффик
(
data.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='city_centers_nearest_km', values='last_price', aggfunc='median')
    .plot(marker='o', grid=True, figsize=(14, 8), legend=False, color='purple', markerfacecolor='yellow')
)
plt.title('Медианная цена объекта недвижимости\nс шагом в 1 км до центра Санкт-Петербурга')
plt.xlabel('км')
plt.ylabel(' 10 млн руб.')
plt.xticks(ticks=np.arange(0,30,1), fontsize=8)
plt.show()
# Out:
#                          last_price
# city_centers_nearest_km
# 0.0                        17900000
# 1.0                        11395000
# 2.0                        10000000
# 3.0                         8400000
# 4.0                         9200000
# 5.0                         9483000
# 6.0                         8895000
# 7.0                         7800000
# 8.0                         7400000
# 9.0                         5300000
# 10.0                        5000000
# 11.0                        5025000
# 12.0                        5000000
# 13.0                        5200000
# 14.0                        4850000
# 15.0                        4900000
# 16.0                        4750000
# 17.0                        4577080
# 18.0                        4300000
# 19.0                        4500000
# 20.0                        5525000
# 21.0                        5289476
# 22.0                        4925000
# 23.0                        4450000
# ...

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# *Наибольшее влияние на стоимость квартиры оказывает её площадь.* Чем больше площадь квартиры (общая, жилая, площадь кухни), тем выше её стоимость. Также на стоимость квартиры влияет и количество комнат. Чем больше комнат, тем выше стоимость. Квартиры с количеством комнат до 4 лучше продаются. Так же из основных параметров влияния на цену объекта - расстояние до центра города. Чем ближе квартира располагается к центру, тем выше ее стоимость.
#
#
# *Типичная квартира представляет из себя:* 1 или 2 комнаты в 6-ти этажке (с квартирой с 2 по 5 этаж), общей площадью около 45 м², жилая площадь - 18 м², а площадь кухни около 8,5 м², с высотой потолков 2,55 м, стоимостью в районе 4 млн.руб, расположенной от центра на 13-14 км, а от аэропорта на 18-25 км, до ближайшего парка около 470 метров. Этаж - первый и последний этажи отнимают % от стоимости квартиры.
#
# Выяснили, что:
#
#  - *Ожидаемое время продажи объекта недвижимости* -  до 120 дней, лучшие показатели времени продажи до 45 дней.
#  - *Самая высокая средняя стоимость квадратного метра из топ-10 городов в Санкт-Петербурге* - 114 733 руб./м².
#  - *Самая низкая средняя стоимость квадратного метра из топ-10 городов в Выборге* - 58 237 руб./м².

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Дополнение к выводу V1</b>
#
# В нашем анализе влияния тех или иных параметров на цену объекта недвижимости мы не рассмотрели такие моменты как окружающая среда (парки, исторические места, транспортная доступность, детские площадки, школы, детские сады, парковочные места около дома), архитектурная и материальная состовляющая дома, класс застройки (массовый, бизнесс, элит). При использование данных параметров можно детальнее расчитать зависимости ценнообразования.
#
#
# В нашем исследовании мы обработали полученный архив данных - обработали пропущенные значения там, где это необходимо, заменили типы данных на необходимые для удобной работы. Посчитали и добавили в таблицу цену квадратного метра жилья, вывели из даты дни недели, месяцы и года размещения объявлений, добавили категории по этажам квартир. Изучили следующие параметры на наличие выбивающихся значений - площадь, цена, число комнат, высота потолков. Были определены аномалии в данных параметрах. Изучая время продажи квартир мы выявили, что большое количество объявлений было автоматически снято или закрыто пользователем. Такую дату из снятия нельзя считать датой продажи квартиры, поэтому, изучая средние сроки продажи квартир - данные значения не учитывались.
# Незначительно на стоимость квадратного метра влияют день, месяц, год размещения объявления.
#
# Также важно учитывать, что, рассматривая среднюю стоимость квартир в 2014-2019 годах, мы не делали сегментацию рынка, а лишь смотрели средние показатели по рынку в целом. Т.е. возможно, что цены на аналогичные квартиры в разных годах вели себя абсолютно по-разному. К примеру в то время, когда средняя стоимость метра по рынку в 2017-2018 годах была наиболее низкой, какие-то аналогичные прошлым годам квартиры могли и не падать в цене, а наоборот дорожать.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В итоговом выводе нужно достаточно подробно написать основные пункты выявленных зависимостей. Стоит доработать вывод с учетом моих комментариев по ходу работы. В итоговом выводе также старайся оставлять рекомендации для последующих шагов. Например рекомендации, что можно обработать и проанализировать другие признаки, на что твоим коллегам стоить обратить внимание.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный вывод, все четко, понятно и структурировано. Вывод в полной мере отражает существующие зависимости, и по нему можно принимать дальнейшие решения.
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Я уверен, что ты приложил все усилия, чтобы сделать этот проект. Это видно по твоей работе, а сформулированные выводы отражают, насколько успешно ты осваиваешь материал.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Ты полностью следовал всем этапам выполнения задания и справился почти со всем. Хорошая работа!
# * Отдельно выделю некоторые выводы, которые ты смог сформулировать абсолютно точно!
# * У тебя опрятный и читаемый код. Возможно это звучит банально, однако при работе с чужим кодом это крайне важно)
#
#
# **На что стоит обратить внимание🤓**:
#
# * Важно доработать итоговый вывод.
# * Нужно корректно рассмотреть зависимость цены от категориальных случайных величин.
# * В последнем пункте посмотри на зависимость общей цены квартир.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Ты отлично справился с данной работой! Видно, как ты успешно осваиваешь материал, применяешь полученные знания на практике. Мне было очень приятно проверять твою работу, надеюсь, мои комментарии и советы были для тебя полезными.
#
# **Желаю удачи в последующем обучении и исследованиях!**😉
